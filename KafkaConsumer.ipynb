# %%
pip install kafka-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 KB 4.2 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json

# %%
PublicIP = '3.238.16.255:9092'#@param {type:"string"}

# %%
consumer = KafkaConsumer(
    'Sales',
     bootstrap_servers=[PublicIP], 
    value_deserializer=lambda x: loads(x.decode('utf-8')))
# Out:
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.

# %%
for count, data in enumerate(consumer):
   print(data.value)
   with open("black_friday_sale_{}.json".format(count), 'w') as file:
        json.dump(data.value, file)
# Out:
# {'User_ID': 1000639, 'Product_ID': 'P00125642', 'Gender': 'M', 'Age': '46-50', 'Occupation': 17, 'City_Category': 'B', 'Stay_In_Current_City_Years': '2', 'Marital_Status': 1, 'Product_Category_1': 5, 'Product_Category_2': 14.0, 'Product_Category_3': nan, 'Purchase': 6992}
# {'User_ID': 1002888, 'Product_ID': 'P00296242', 'Gender': 'M', 'Age': '26-35', 'Occupation': 14, 'City_Category': 'B', 'Stay_In_Current_City_Years': '2', 'Marital_Status': 1, 'Product_Category_1': 8, 'Product_Category_2': nan, 'Product_Category_3': nan, 'Purchase': 5888}
# {'User_ID': 1004188, 'Product_ID': 'P00121242', 'Gender': 'M', 'Age': '51-55', 'Occupation': 7, 'City_Category': 'C', 'Stay_In_Current_City_Years': '3', 'Marital_Status': 0, 'Product_Category_1': 2, 'Product_Category_2': nan, 'Product_Category_3': nan, 'Purchase': 12969}
# {'User_ID': 1004526, 'Product_ID': 'P00343042', 'Gender': 'M', 'Age': '26-35', 'Occupation': 20, 'City_Category': 'B', 'Stay_In_Current_City_Years': '2', 'Marital_Status': 1, 'Product_Category_1': 5, 'Product_Category_2': 18.0, 'Product_Category_3': nan, 'Purchase': 5368}
# {'User_ID': 1004490, 'Product_ID': 'P0096842', 'Gender': 'M', 'Age': '36-45', 'Occupation': 5, 'City_Category': 'B', 'Stay_In_Current_City_Years': '1', 'Marital_Status': 0, 'Product_Category_1': 3, 'Product_Category_2': 4.0, 'Product_Category_3': 12.0, 'Purchase': 13277}
# {'User_ID': 1000355, 'Product_ID': 'P00328142', 'Gender': 'M', 'Age': '18-25', 'Occupation': 3, 'City_Category': 'B', 'Stay_In_Current_City_Years': '2', 'Marital_Status': 0, 'Product_Category_1': 8, 'Product_Category_2': 16.0, 'Product_Category_3': nan, 'Purchase': 8133}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a9f6ef371d9c> in <module>
# ----> 1 for count, data in enumerate(consumer):
#       2    print(data.value)
#       3    with open("black_friday_sale_{}.json".format(count), 'w') as file:
#       4         json.dump(data.value, file)
#
# /usr/local/lib/python3.8/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.8/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.8/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.8/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.8/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.8/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.8/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.8/selectors.py in select(self, timeout)
#     466             ready = []
#     467             try:
# --> 468                 fd_event_list = self._selector.poll(timeout, max_ev)
#     469             except InterruptedError:
#     470                 return ready
#
# KeyboardInterrupt:
